# %%
#https://www.kaggle.com/jessicali9530/honey-production
    
# get data set from here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read Honey Production Dataset.

hp = pd.read_csv('C:/Users/Lenovo/Desktop/DataFrame for pandas/honeyproduction.csv')

# %%
hp.shape
# Out:
# (626, 8)

# %%
hp.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
hp.tail()
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %%
hp
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# 4     1361000.0  1998
# ..          ...   ...
# 621    618000.0  2012
# 622   6050000.0  2012
# 623    838000.0  2012
# 624   8487000.0  2012
# 625   4769000.0  2012
#
# [626 rows x 8 columns]

# %%
# Summerizing hp dataset

hp.describe().transpose()
# Out:
#              count          mean           std        min          25%  \
# numcol       626.0  6.028435e+04  9.107709e+04    2000.00    9000.0000
# yieldpercol  626.0  6.200958e+01  1.945875e+01      19.00      48.0000
# totalprod    626.0  4.169086e+06  6.883847e+06   84000.00  475000.0000
# stocks       626.0  1.318859e+06  2.272964e+06    8000.00  143000.0000
# priceperlb   626.0  1.409569e+00  6.385989e-01       0.49       0.9325
# prodvalue    626.0  4.715741e+06  7.976110e+06  162000.00  759250.0000
# year         626.0  2.004864e+03  4.317306e+00    1998.00    2001.0000
#
#                     50%         75%          max
# numcol         26000.00    63750.00    510000.00
# yieldpercol       60.00       74.00       136.00
# totalprod    1533000.00  4175250.00  46410000.00
# stocks        439500.00  1489500.00  13800000.00
# priceperlb         1.36        1.68         4.15
# prodvalue    1841500.00  4703250.00  69615000.00
# year            2005.00     2009.00      2012.00

# %%
# Creating summmary table to understand the trend using year variable

hp_year = hp[['numcol','totalprod','year','yieldpercol','stocks','prodvalue']].groupby('year').sum()
#.groupby ("year").sum()
hp_year
# Out:
#          numcol    totalprod  yieldpercol      stocks    prodvalue
# year
# 1998  2621000.0  219519000.0         3008  80565000.0  146091000.0
# 1999  2637000.0  202387000.0         2815  78390000.0  123657000.0
# 2000  2604000.0  219558000.0         2906  84956000.0  131568000.0
# 2001  2542000.0  185748000.0         2840  64764000.0  132282000.0
# 2002  2565000.0  171265000.0         2939  39177000.0  227302000.0
# 2003  2591000.0  181372000.0         2752  40619000.0  252079000.0
# 2004  2539000.0  182729000.0         2657  60981000.0  197307000.0
# 2005  2394000.0  173969000.0         2635  62187000.0  160793000.0
# 2006  2378000.0  154238000.0         2536  60235000.0  157924000.0
# 2007  2428000.0  147621000.0         2426  52405000.0  161356000.0
# 2008  2326000.0  162972000.0         2501  50996000.0  229992000.0
# 2009  2472000.0  145068000.0         2154  37322000.0  213920000.0
# 2010  2666000.0  175294000.0         2251  44797000.0  278370000.0
# 2011  2466000.0  147201000.0         2191  36550000.0  258688000.0
# 2012  2509000.0  140907000.0         2207  31662000.0  280725000.0

# %%
hp_year.head()
# Out:
#          numcol    totalprod  yieldpercol      stocks    prodvalue
# year
# 1998  2621000.0  219519000.0         3008  80565000.0  146091000.0
# 1999  2637000.0  202387000.0         2815  78390000.0  123657000.0
# 2000  2604000.0  219558000.0         2906  84956000.0  131568000.0
# 2001  2542000.0  185748000.0         2840  64764000.0  132282000.0
# 2002  2565000.0  171265000.0         2939  39177000.0  227302000.0

# %%
hp_year.reset_index(inplace = True)
hp_year.head()
# Out:
#    index  year     numcol    totalprod  yieldpercol      stocks    prodvalue
# 0      0  1998  2621000.0  219519000.0         3008  80565000.0  146091000.0
# 1      1  1999  2637000.0  202387000.0         2815  78390000.0  123657000.0
# 2      2  2000  2604000.0  219558000.0         2906  84956000.0  131568000.0
# 3      3  2001  2542000.0  185748000.0         2840  64764000.0  132282000.0
# 4      4  2002  2565000.0  171265000.0         2939  39177000.0  227302000.0

# %%
hp
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# 4     1361000.0  1998
# ..          ...   ...
# 621    618000.0  2012
# 622   6050000.0  2012
# 623    838000.0  2012
# 624   8487000.0  2012
# 625   4769000.0  2012
#
# [626 rows x 8 columns]

# %%
# visualizing the trend of Yield per colony from 1998 to 2012
plt.figure(figsize= (25,8))
plt.plot(hp_year['year'],hp_year['yieldpercol'])
plt.title('Trend of honey Yield per Colony', fontsize= 25)
plt.xlabel('Year',fontsize= 25)
plt.ylabel('Yield per colony', fontsize = 25)
# Out:
# Text(0, 0.5, 'Yield per colony')

# %%
# Visualizing the total honey production from the year 1998 to 2012.

plt.figure(figsize=( 30,10))
plt.plot(hp_year['year'], hp_year['totalprod'])
plt.title('Total honey production in USA', fontsize = 25)
plt.xlabel('year', fontsize = 25)
plt.ylabel('total Production of honey (Lbs.)', fontsize = 25)
# Out:
# Text(0, 0.5, 'total Production of honey (Lbs.)')

# %%
# Group the dataset by states and using sum method to get the total honey production value in descending order.

US_state = hp[['state','totalprod','yieldpercol']].groupby('state').sum()
US_state.reset_index(level=0, inplace=True)
US_state.sort_values(by='totalprod', ascending=False,inplace=True)
US_state
# Out:
#    state    totalprod  yieldpercol
# 23    ND  475085000.0         1321
# 3     CA  347535000.0          837
# 34    SD  266141000.0         1137
# 5     FL  247048000.0         1246
# 21    MT  156562000.0         1160
# 18    MN  144360000.0         1114
# 36    TX  104904000.0         1058
# 41    WI   81833000.0         1191
# 17    MI   72820000.0         1022
# 9     ID   66160000.0          660
# 28    NY   59062000.0         1037
# 14    LA   54410000.0         1436
# 6     GA   49499000.0          820
# 24    NE   47379000.0         1012
# 1     AR   42156000.0         1109
# 40    WA   40316000.0          732
# 43    WY   39269000.0          992
# 31    OR   31821000.0          666
# 8     IA   31200000.0          986
# 2     AZ   30484000.0          901
# 4     CO   26259000.0          942
# 20    MS   21853000.0         1312
# 32    PA   19434000.0          756
# 37    UT   17686000.0          698
# 29    OH   15601000.0          953
# 19    MO   13073000.0          801
# 7     HI   12647000.0         1470
# 0     AL   12382000.0         1013
# 12    KS   10619000.0          841
# 22    NC    8141000.0          717
# 10    IL    7475000.0          925
# 11    IN    7260000.0          914
# 26    NM    7147000.0          808
# 35    TN    6116000.0          845
# 25    NJ    5993000.0          554
# 39    VT    5821000.0         1004
# 27    NV    4832000.0          497
# 42    WV    4818000.0          728
# 38    VA    3998000.0          603
# 16    ME    3701000.0          466
# 13    KY    3445000.0          782
# 15    MD    1266000.0          270
# 30    OK    1207000.0          278
# 33    SC    1030000.0          204

# %%
US_state.head()
# Out:
#    state    totalprod  yieldpercol
# 23    ND  475085000.0         1321
# 3     CA  347535000.0          837
# 34    SD  266141000.0         1137
# 5     FL  247048000.0         1246
# 21    MT  156562000.0         1160

# %%
# Creating a Bar chart to vizualize the total honey production by state.

plt.figure(figsize=(30,8))
sns.barplot(x=US_state['state'], y = US_state['totalprod'])
plt.title('Statewise total honey production in USA', fontsize = 25)
plt.xlabel('State', fontsize = 25)
plt.ylabel('Total production of honey in USA', fontsize= 25)
# Out:
# Text(0, 0.5, 'Total production of honey in USA')

# %%
# Create a table to find out the maximum production value from the states

US_state_max = hp[['state','totalprod']].groupby('state').max()
US_state_max.reset_index(inplace = True)

# %%
US_state_max.columns = ['State','Max Prod']
US_state_max.head()
# Out:
#   State    Max Prod
# 0    AL   1248000.0
# 1    AR   4900000.0
# 2    AZ   3300000.0
# 3    CA  37350000.0
# 4    CO   2700000.0

# %%
# Creating a table to find out minimum production value from the states

US_state_min = hp[['state','totalprod']].groupby('state').min()
US_state_min.reset_index(inplace = True)
US_state_min.columns = ['State','Min Prod']
US_state_min.head()
# Out:
#   State    Min Prod
# 0    AL    432000.0
# 1    AR   1368000.0
# 2    AZ   1012000.0
# 3    CA  11550000.0
# 4    CO   1200000.0

# %%
# merging theMax Prod and Min Prod variable to find the range.

st_range = pd.merge(US_state_max,US_state_min,how='inner',on='State')
st_range.head()
# Out:
#   State    Max Prod    Min Prod
# 0    AL   1248000.0    432000.0
# 1    AR   4900000.0   1368000.0
# 2    AZ   3300000.0   1012000.0
# 3    CA  37350000.0  11550000.0
# 4    CO   2700000.0   1200000.0

# %%
st_range
# Out:
#    State    Max Prod    Min Prod  Per_Change
# 19    MO   1725000.0    344000.0   80.057971
# 26    NM    960000.0    246000.0   74.375000
# 16    ME    451000.0    120000.0   73.392461
# 15    MD    308000.0     84000.0   72.727273
# 12    KS   1120000.0    308000.0   72.500000
# 39    VT    623000.0    172000.0   72.391653
# 1     AR   4900000.0   1368000.0   72.081633
# 8     IA   3900000.0   1092000.0   72.000000
# 2     AZ   3300000.0   1012000.0   69.333333
# 3     CA  37350000.0  11550000.0   69.076305
# 43    WY   3627000.0   1224000.0   66.253102
# 11    IN    828000.0    280000.0   66.183575
# 38    VA    468000.0    160000.0   65.811966
# 0     AL   1248000.0    432000.0   65.384615
# 25    NJ    539000.0    190000.0   64.749536
# 27    NV    770000.0    280000.0   63.636364
# 29    OH   1480000.0    550000.0   62.837838
# 34    SD  28435000.0  10575000.0   62.809917
# 42    WV    495000.0    185000.0   62.626263
# 10    IL    720000.0    272000.0   62.222222
# 22    NC    868000.0    360000.0   58.525346
# 9     ID   6300000.0   2619000.0   58.428571
# 35    TN    549000.0    240000.0   56.284153
# 28    NY   5880000.0   2601000.0   55.765306
# 41    WI   8099000.0   3591000.0   55.661193
# 4     CO   2700000.0   1200000.0   55.555556
# 13    KY    335000.0    150000.0   55.223881
# 37    UT   1740000.0    780000.0   55.172414
# 5     FL  24360000.0  10980000.0   54.926108
# 24    NE   4539000.0   2064000.0   54.527429
# 18    MN  13500000.0   6360000.0   52.888889
# 14    LA   5472000.0   2581000.0   52.832602
# 36    TX   9380000.0   4524000.0   51.769723
# 32    PA   1716000.0    840000.0   51.048951
# 23    ND  46410000.0  24000000.0   48.287007
# 30    OK    270000.0    141000.0   47.777778
# 20    MS   2124000.0   1122000.0   47.175141
# 21    MT  14030000.0   7540000.0   46.258019
# 6     GA   4662000.0   2530000.0   45.731446
# 7     HI   1179000.0    640000.0   45.716709
# 40    WA   3528000.0   2024000.0   42.630385
# 17    MI   6800000.0   3960000.0   41.764706
# 33    SC    470000.0    280000.0   40.425532
# 31    OR   2565000.0   1638000.0   36.140351

# %%
# Create a Per_change Column in the st_range dataset to understand honey production chhanges by states.

st_range['Per_Change'] = ((st_range['Max Prod'] - st_range['Min Prod'])/ st_range['Max Prod'])*100
st_range.sort_values(by = 'Per_Change', ascending = False, inplace = True)
st_range.head()
# Out:
#    State   Max Prod  Min Prod  Per_Change
# 19    MO  1725000.0  344000.0   80.057971
# 26    NM   960000.0  246000.0   74.375000
# 16    ME   451000.0  120000.0   73.392461
# 15    MD   308000.0   84000.0   72.727273
# 12    KS  1120000.0  308000.0   72.500000

# %%
# Create a BAr chart to visualize the statewise decline trend.

plt.figure(figsize= (30, 10))
sns.barplot(x = 'State', y = "Per_Change", data = st_range)
plt.title('Statewise Production Decline Trend', fontsize = 25)
plt.xlabel("State", fontsize = 25)
plt.ylabel('% Decline ', fontsize = 25)
# Out:
# Text(0, 0.5, '% Decline ')

# %%
# Checking the correlation between variables
honey_corr = hp[['numcol','totalprod','year','yieldpercol','stocks','prodvalue']].corr()

honey_corr
# Out:
#                numcol  totalprod      year  yieldpercol    stocks  prodvalue
# numcol       1.000000   0.953594  0.008709     0.243515  0.825929   0.912796
# totalprod    0.953594   1.000000 -0.055556     0.396252  0.878830   0.907236
# year         0.008709  -0.055556  1.000000    -0.232092 -0.119602   0.139451
# yieldpercol  0.243515   0.396252 -0.232092     1.000000  0.367812   0.278977
# stocks       0.825929   0.878830 -0.119602     0.367812  1.000000   0.728560
# prodvalue    0.912796   0.907236  0.139451     0.278977  0.728560   1.000000

# %%
# Visualize the same in Heatmap()
sns.heatmap(honey_corr, annot = True, vmin = -1, vmax = 1, cmap='YlGnBu')
plt.show()

# %%
# Checking hypothesis: "more the number of colonies, higher the production value"

sns.lmplot(x = "numcol", y = "prodvalue", data = hp, hue = 'year')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(hp.drop(['totalprod','state'], axis = 1),
                                                    hp['totalprod'], test_size = 0.20,
                                                    random_state = 8)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
accuracy = model.score(X_test, Y_test)
print(accuracy* 100, '%')
# Out:
# 95.25114307242252 %
